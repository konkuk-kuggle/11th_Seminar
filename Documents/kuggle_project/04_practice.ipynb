# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns 

anscombe = sns.load_dataset("anscombe") 
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
# %matplotlib inline #matplotlib: 그래프 그리기 위한 라이브러리
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I'] #데이터 값 I인 것만 추출

# %%
plt.plot(dataset_1['x'], dataset_1['y']) #plot메서드에 x,y축 데이터 전달

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o') #점으로 그리기

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure() #격자가 위치할 기본틀 만들기

#add_subplot메서드로 기본 틀에 격자 추가
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
#set_title: 그래프에 제목 추가
axes1.set_title("dataset_1") 
axes2.set_title("dataset_2")
axes3.set_title("dataset_3") 
axes4.set_title("dataset_4")

fig

# %%
#기본틀(fig)에도 제목 추가
fig.suptitle("Anscombe Data")

fig

# %%
#그림, 이름, 숫자 겹쳐지는 거 방지
fig.tight_layout()

fig

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() #기본 틀 마련
axes1 = fig.add_subplot(1, 1, 1) #그래프 격자 구성

# %%
#히스토그램(일변량 그래프) 만들기: hist메서드에 total_bill열 전달
axes1.hist(tips['total_bill'], bins=10) #bins: x축 간격
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill') 

fig

# %%
#산점도 그래프(이변량 그래프, 변수 2개) 그리기
scatter_plot = plt.figure() #기본 틀
axes1 = scatter_plot.add_subplot(1, 1, 1) #격자

#scatter메서드에 열 전달
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#박스 그래프 그리기
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\3277955139.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes1.boxplot(
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
#seaborn라이브러리로 히스토그램 그리기
#subplots메서드로 기본틀 만들기> distplots메서드에 total_bill열데이터 전달

ax = plt.subplots()
ax = sns.distplot(tips['total_bill']) 
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\3492999047.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
#밀집도 그래프(선 그래프) 없애기 
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], kde=False) #kde 인잣값 False로 설정
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\2906368944.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False) #kde 인잣값 False로 설정
# Text(0, 0.5, 'Frequency')

# %%
#밀집도 그래프'만' 나다내기
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist=False) #hist인자 False로 지정
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')

# %%
#여러 그래프 한 번에 출력하기
hist_den_rug, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], rug=True) #rug 그래프까지 그리기
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\2750630008.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True) #rug 그래프까지 그리기
# Text(0.5, 0, 'Total Bill')

# %%
#count 그래프(이산값)
ax = plt.subplots() 
ax = sns.countplot('day', data=tips) 
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 ax = plt.subplots()
# ----> 2 ax = sns.countplot('day', data=tips)
#       3 ax.set_title('Count of days')
#       4 ax.set_xlabel('Day of the Week')
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# # 다변량 그래프 그리기

# %%
#산점도 그래프
#색상 구별하기 위해 정수 사용. 여자면 0, 남자면 1
def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(
    x=tips['total_bill'], 
    y=tips['tip'],    
    s=tips['size'] * 10,    #인원 수 size
    c=tips['sex_color'],
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#seaborn라이브러리로 산점도 그래프 그리기
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) #회귀선 지우기
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#산점도 색상추가
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False) 
plt.show()

# %%
#산점도 크기 조절
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10}) 
plt.show()

# %%
#산점도 그래프 점 다른 기호로
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10}) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 2
#       1 #산점도 그래프 점 다른 기호로
# ----> 2 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10})
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\regression.py:651, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
#     644     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
# ...

# %%
#lmplot메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %%
#jointplot메서드: 산점도, 히스토그램 한 번에 그리기
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
#육각그래프(hexbin)로 데이터 쉽게 구분하기
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex") 
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1696: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   f = plt.figure(figsize=(height, height))
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
#kdeplot: 이차원 밀집도 그리기
kde, ax = plt.subplots() 
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], 
                 shade=True) #음영효과
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 #kdeplot: 이차원 밀집도 그리기
#       2 kde, ax = plt.subplots()
# ----> 3 ax = sns.kdeplot(data=tips['total_bill'],
#       4                  data2=tips['tip'],
#       5                  shade=True) #음영효과
#       6 ax.set_title('Kernel Density Plot of Total Bill and Tip')
#       7 ax.set_xlabel('Total Bill')
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1596, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1594 if "data2" in kwargs:
#    1595     msg = "`data2` has been removed (replaced by `y`); please update your code."
# -> 1596     raise TypeError(msg)
# ...

# %%
#바 그래프 그리기(평균 이용) 
ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
#박스 그래프 그리기(최솟값, 1분위수, 중간값, 3분위수, 최댓값, 이상치)
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#violinplot: 바이올린 그래프
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#바이올린 색상추가
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True) 
plt.show()

# %%
#관계그래프
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) #대각선 위쪽에 산점도 그래프 
pair_grid = pair_grid.map_lower(sns.kdeplot) #대각선 아래쪽에 이차원 밀집도 그래프 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) #대각선 중심으로 히스토그램과 밀집도 그래프 
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#관계 그래프 색상추가
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax) #투명도 조절

# %%
#밀집도- kde, 산점도-scatter, 육각-hexbin

fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde() 

fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax) 

fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\3337114941.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()

# %%
#육각 그래프의 크기-gridsize
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
#box메서드
fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)

# %%
#그래프에 스타일 적용하기
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
#whitegrid스타일 설정-가로줄 생김
sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
#for문으로 모든 스타일 하나씩 적용
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()

# %% [markdown]
# # 알아두면 좋아요

# %%
#facetgrid클래스 사용해 간편히 그래프 그리기
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#다변량그래프
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %%
#더많은 변수
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')
